# %% [markdown]
# <a href="https://colab.research.google.com/github/AdriGruartM/AD2/blob/main/AD_Estaciones_calidad_aire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos las librerías que queremos utilizar

# %%
import csv
import pandas as pd

from google.colab import files
upload = files.upload()

data = pd.read_csv('/content/drive/MyDrive/2023_qualitat_aire_estacions.csv') #link https://opendata-ajuntament.barcelona.cat/data/es/dataset/qualitat-aire-estacions-bcn #

filename = '2023_qualitat_aire_estacions.csv'
keys = ('Longitud', 'Latitud', 'Nom_barri')
records = []

with open(filename, 'r') as csvfile:
  reader = csv.DictReader(csvfile)
  for row in reader:
    records.append({key: row[key] for key in keys})
# Out:
#      <input type="file" id="files-06d1bc29-9182-48c8-b62f-5445f14d21c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06d1bc29-9182-48c8-b62f-5445f14d21c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(records[0])
# Out:
# {'Longitud': '2.2045', 'Latitud': '41.4039', 'Nom_barri': 'el Poblenou'}

# %%
for record in records:
  Longitud = record['Longitud']
  Latitud = record['Latitud']
  
  record['Longitud'] = float(Longitud)
  record['Latitud'] = float(Latitud)

# %%
records[0]
# Out:
# {'Longitud': 2.2045, 'Latitud': 41.4039, 'Nom_barri': 'el Poblenou'}

# %%
import folium

map = folium.Map(location=[41.382778, 2.176944], zoom_start=9)

for record in records:
  coords = (record['Latitud'], record['Longitud'])
  folium.Marker(coords, popup=record['Nom_barri']).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Nueva sección
